# %%
import cv2 
from google.colab.patches import cv2_imshow
import pandas as pd

# %%
img_path = "/content/input.jpg" 
img = cv2.imread(img_path) 
cv2_imshow(img)

print("\n")

# Resizing using Bicubic Interpolation
resized_img = cv2.resize(img,(150, 110), interpolation=cv2.INTER_CUBIC)
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FCAA716EAD0>
# <PIL.Image.Image image mode=RGB size=150x110 at 0x7FCAA716E290>
